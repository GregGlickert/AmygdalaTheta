# %%
# !pip install neuron bmtk bmtool

# %%
from bmtool import bmplot
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bmplot.convergence_connection_matrix(config="simulation_configECP_base_homogenous.json",sources= "all", targets="all")
plt.show()
# Out:
# ValueError('Length of values (110027) does not match length of index (118676)')
# Hint: Are you loading the correct simulation config file?
# Command Line: bmtool plot --config yourconfig.json <rest of command>
# Python: bmplot.connection_matrix(config='yourconfig.json')
# /home/gjgpb9/miniconda3/envs/cpu_bmtk/lib/python3.8/site-packages/bmtool/bmplot.py:278: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig1.show()
